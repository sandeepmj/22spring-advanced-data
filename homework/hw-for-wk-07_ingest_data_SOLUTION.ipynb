# %% [markdown]
# ## Pandas - Importing data
#
# All the data for the questions below can be <a href="https://www.dropbox.com/s/vddd7gz598w26mi/wk7-data.zip?dl=0">found in this zipped folder</a>.
#
# **Give yourself time to download it. Some of the files are large!**

# %%
## import the pandas library in this cell
import pandas as pd

# %% [markdown]
# ### Ingest the following dataset into this note:
#
# - ```ems_2019_first_6_months.csv``` into a dataframe named ```ems_19_first_df```

# %%
## import data and store in dataframe
ems_19_first_df = pd.read_csv("wk7-data/ems_2019_first_6_months.csv")

# %%
## call the first 10 rows
ems_19_first_df.head(10)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        190010111  2019-01-01 00:24:51              SICK
# 1        190010112  2019-01-01 00:25:22              DRUG
# 2        190010113  2019-01-01 00:25:52              DRUG
# 3        190010114  2019-01-01 00:25:52             OBMAJ
# 4        190010115  2019-01-01 00:26:03               EDP
# 5        190073272  2019-01-07 17:49:43               EDP
# 6        190073416  2019-01-07 18:27:54               EDP
# 7        190081434  2019-01-08 10:28:31            UNKNOW
# 8        190081743  2019-01-08 11:43:35            UNKNOW
# 9        190081744  2019-01-08 11:43:48               EDP
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            6            SICK                          6
# 1                            4            DRUG                          4
# 2                            4            DRUG                          4
# 3                            3           OBMAJ                          3
# 4                            7             EDP                          7
# 5                            7             EDP                          7
# 6                            7             EDP                          7
# 7                            4          UNKNOW                          4
# 8                            4          UNKNOW                          4
# 9                            7             EDP                          7
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    01/01/2019 12:25:28 AM                              Y
# 1    01/01/2019 12:25:39 AM                              Y
# 2    01/01/2019 12:25:57 AM                              Y
# 3    01/01/2019 12:26:13 AM                              Y
# 4    01/01/2019 12:26:12 AM                              Y
# 5    01/07/2019 05:49:50 PM                              Y
# 6    01/07/2019 06:28:33 PM                              Y
# 7    01/08/2019 10:29:19 AM                              Y
# 8    01/08/2019 11:43:47 AM                              Y
# 9    01/08/2019 11:43:59 AM                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT  \
# 0                            37    01/01/2019 12:25:56 AM  ...            9.0
# 1                            17    01/01/2019 12:26:03 AM  ...           23.0
# 2                             5    01/01/2019 12:26:11 AM  ...           63.0
# 3                            21    01/01/2019 12:26:24 AM  ...          106.0
# 4                             9    01/01/2019 12:26:29 AM  ...          101.0
# 5                             7    01/07/2019 05:50:04 PM  ...           17.0
# 6                            39    01/07/2019 06:28:44 PM  ...            6.0
# 7                            48    01/08/2019 10:29:36 AM  ...            NaN
# 8                            12    01/08/2019 11:43:55 AM  ...            7.0
# 9                            11    01/08/2019 11:44:30 AM  ...           44.0
#
#   CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT  \
# 0                 2.0              103.0                      1.0
# 1                 9.0              111.0                      4.0
# 2                45.0              318.0                     22.0
# 3                32.0              410.0                     27.0
# 4                31.0              414.0                     27.0
# 5                 5.0              106.0                      2.0
# 6                 3.0              102.0                      2.0
# 7                 NaN                NaN                      NaN
# 8                 1.0              103.0                      2.0
# 9                16.0              204.0                      9.0
#
#   CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 0                  12.0                N                       N
# 1                  13.0                N                       N
# 2                   8.0                N                       N
# 3                   8.0                N                       N
# 4                   5.0                N                       N
# 5                  12.0                N                       N
# 6                  10.0                N                       N
# 7                   NaN                N                       N
# 8                  12.0                N                       N
# 9                  15.0                N                       N
#
#   STANDBY_INDICATOR  TRANSFER_INDICATOR        source
# 0                 N                   N   chunk10.csv
# 1                 N                   N   chunk10.csv
# 2                 N                   N   chunk13.csv
# 3                 N                   N   chunk14.csv
# 4                 N                   N   chunk14.csv
# 5                 N                   N  chunk149.csv
# 6                 N                   N  chunk149.csv
# 7                 N                   N  chunk149.csv
# 8                 N                   N  chunk149.csv
# 9                 N                   N  chunk149.csv
#
# [10 rows x 32 columns]

# %%
## call the last 5 rows
ems_19_first_df.tail()
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 754651        190010106  2019-01-01 00:24:12              DRUG
# 754652        190010107  2019-01-01 00:24:14               UNC
# 754653        190010108  2019-01-01 00:24:16            INJMAJ
# 754654        190010109  2019-01-01 00:24:23              CARD
# 754655        190010110  2019-01-01 00:24:35              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 754651                            4            DRUG
# 754652                            2             UNC
# 754653                            3          INJMAJ
# 754654                            3            CARD
# 754655                            4            DRUG
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 754651                          4    01/01/2019 12:28:52 AM
# 754652                          2    01/01/2019 12:24:38 AM
# 754653                          3    01/01/2019 12:25:50 AM
# 754654                          3    01/01/2019 12:25:08 AM
# 754655                          4    01/01/2019 12:25:28 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 754651                              Y                           280
# 754652                              Y                            24
# 754653                              Y                            94
# 754654                              Y                            45
# 754655                              Y                            53
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 754651    01/01/2019 12:28:52 AM  ...           14.0                 3.0
# 754652    01/01/2019 12:24:57 AM  ...           14.0                 3.0
# 754653    01/01/2019 12:25:50 AM  ...           18.0                 4.0
# 754654    01/01/2019 12:25:27 AM  ...           50.0                14.0
# 754655    01/01/2019 12:25:40 AM  ...           62.0                47.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 754651              105.0                      2.0                  12.0
# 754652              105.0                      2.0                  12.0
# 754653              105.0                      2.0                  12.0
# 754654              208.0                     10.0                  13.0
# 754655              311.0                     20.0                  10.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 754651                N                       N                 N
# 754652                N                       N                 N
# 754653                N                       N                 N
# 754654                N                       N                 N
# 754655                N                       N                 N
#
#         TRANSFER_INDICATOR       source
# 754651                   N  chunk82.csv
# 754652                   N  chunk82.csv
# 754653                   N  chunk82.csv
# 754654                   N  chunk82.csv
# 754655                   N  chunk82.csv
#
# [5 rows x 32 columns]

# %%
## call a 20 random rows
ems_19_first_df.sample(20)
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 519743        191310410  2019-05-11 02:01:18            SICMIN
# 368562        190942999  2019-04-04 16:11:10            INJURY
# 69352         190202369  2019-01-20 15:14:52             ANAPH
# 647291        191601300  2019-06-09 08:24:28              DRUG
# 206609        190543166  2019-02-23 18:47:40              CARD
# 711267        191744572  2019-06-23 22:32:01            UNKNOW
# 115247        190320647  2019-02-01 06:42:52            STNDBY
# 230896        190604329  2019-03-01 23:05:18            DIFFBR
# 151308        190402747  2019-02-09 17:21:26              SICK
# 701214        191723372  2019-06-21 17:26:53            CARDBR
# 389945        190993345  2019-04-09 17:49:48               EDP
# 753712        190052231  2019-01-05 13:23:53              SICK
# 326685        190842288  2019-03-25 13:48:21              SAFE
# 147203        190393044  2019-02-08 16:24:57              SICK
# 657247        191622837  2019-06-11 15:51:04            MVAINJ
# 605835        191510038  2019-05-31 00:14:32            PEDSTR
# 443046        191122403  2019-04-22 14:46:46             OTHER
# 333269        190860596  2019-03-27 04:47:40              SICK
# 641364        191584703  2019-06-07 22:05:25              DRUG
# 412721        191050674  2019-04-15 05:52:17              SICK
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 519743                            7            SICK
# 368562                            5          INJURY
# 69352                             2           ANAPH
# 647291                            4            DRUG
# 206609                            3            CARD
# 711267                            4          UNKNOW
# 115247                            8          STNDBY
# 230896                            2          DIFFBR
# 151308                            6            SICK
# 701214                            2          CARDBR
# 389945                            7             EDP
# 753712                            6            SICK
# 326685                            6            SAFE
# 147203                            6            SICK
# 657247                            4          MVAINJ
# 605835                            3          PEDSTR
# 443046                            6           OTHER
# 333269                            6            SICK
# 641364                            4            DRUG
# 412721                            6            SICK
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 519743                          6    05/11/2019 02:02:00 AM
# 368562                          5    04/04/2019 04:11:32 PM
# 69352                           2    01/20/2019 03:14:56 PM
# 647291                          4    06/09/2019 08:24:47 AM
# 206609                          3    02/23/2019 06:48:10 PM
# 711267                          4    06/23/2019 10:32:43 PM
# 115247                          8    02/01/2019 07:20:35 AM
# 230896                          2    03/01/2019 11:05:33 PM
# 151308                          6    02/09/2019 05:21:39 PM
# 701214                          2    06/21/2019 05:27:02 PM
# 389945                          7    04/09/2019 05:50:16 PM
# 753712                          6    01/05/2019 01:24:08 PM
# 326685                          6    03/25/2019 01:49:23 PM
# 147203                          6    02/08/2019 04:26:53 PM
# 657247                          4    06/11/2019 03:51:28 PM
# 605835                          3    05/31/2019 12:14:54 AM
# 443046                          6    04/22/2019 03:31:22 PM
# 333269                          6    03/27/2019 04:49:23 AM
# 641364                          4    06/07/2019 10:05:37 PM
# 412721                          6    04/15/2019 06:08:32 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 519743                              Y                            42
# 368562                              Y                            22
# 69352                               Y                             4
# 647291                              Y                            19
# 206609                              Y                            30
# 711267                              Y                            42
# 115247                              Y                          2263
# 230896                              Y                            15
# 151308                              Y                            13
# 701214                              Y                             9
# 389945                              Y                            28
# 753712                              Y                            15
# 326685                              Y                            62
# 147203                              Y                           116
# 657247                              Y                            24
# 605835                              Y                            22
# 443046                              Y                          2676
# 333269                              Y                           103
# 641364                              Y                            12
# 412721                              Y                           975
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 519743    05/11/2019 02:02:17 AM  ...           81.0                36.0
# 368562    04/04/2019 04:11:45 PM  ...          111.0                19.0
# 69352     01/20/2019 03:15:42 PM  ...           33.0                10.0
# 647291    06/09/2019 08:25:28 AM  ...          104.0                30.0
# 206609    02/23/2019 06:48:18 PM  ...          104.0                30.0
# 711267    06/23/2019 10:32:49 PM  ...           60.0                47.0
# 115247    02/01/2019 07:21:40 AM  ...          108.0                26.0
# 230896    03/01/2019 11:06:27 PM  ...           76.0                39.0
# 151308    02/09/2019 05:22:01 PM  ...           62.0                47.0
# 701214    06/21/2019 05:27:09 PM  ...           30.0                 7.0
# 389945    04/09/2019 05:50:31 PM  ...           81.0                36.0
# 753712    01/05/2019 01:24:26 PM  ...          104.0                30.0
# 326685    03/25/2019 01:49:34 PM  ...           48.0                15.0
# 147203    02/08/2019 04:27:37 PM  ...           84.0                33.0
# 657247    06/11/2019 03:51:51 PM  ...            NaN                 NaN
# 605835    05/31/2019 12:15:18 AM  ...          115.0                21.0
# 443046    04/22/2019 03:31:33 PM  ...           25.0                 8.0
# 333269    03/27/2019 04:49:36 AM  ...           70.0                45.0
# 641364    06/07/2019 10:06:24 PM  ...           78.0                39.0
# 412721    04/15/2019 06:08:44 AM  ...           48.0                15.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 519743              303.0                     16.0                   8.0
# 368562              411.0                     26.0                   6.0
# 69352               112.0                      6.0                  13.0
# 647291              405.0                     24.0                   6.0
# 206609              405.0                     24.0                   6.0
# 711267              313.0                     21.0                   8.0
# 115247              402.0                     30.0                  12.0
# 230896              306.0                     15.0                   7.0
# 151308              311.0                     21.0                  10.0
# 701214              109.0                      6.0                  13.0
# 389945              303.0                     16.0                   8.0
# 753712              405.0                     24.0                   6.0
# 326685              206.0                     10.0                  15.0
# 147203              302.0                     15.0                   7.0
# 657247                NaN                      NaN                   NaN
# 605835              403.0                     30.0                  14.0
# 443046              111.0                      5.0                  13.0
# 333269              314.0                     22.0                   9.0
# 641364              355.0                     17.0                   9.0
# 412721              206.0                     10.0                  15.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 519743                N                       N                 N
# 368562                N                       N                 N
# 69352                 N                       N                 N
# 647291                N                       N                 N
# 206609                N                       N                 N
# 711267                N                       N                 N
# 115247                Y                       N                 Y
# 230896                N                       N                 N
# 151308                N                       N                 N
# 701214                N                       N                 N
# 389945                N                       N                 N
# 753712                N                       N                 N
# 326685                N                       N                 N
# 147203                N                       N                 N
# 657247                N                       N                 N
# 605835                N                       N                 N
# 443046                N                       N                 N
# 333269                N                       N                 N
# 641364                N                       N                 N
# 412721                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 519743                   N  chunk155.csv
# 368562                   N  chunk153.csv
# 69352                    N  chunk150.csv
# 647291                   N  chunk156.csv
# 206609                   N  chunk151.csv
# 711267                   N  chunk156.csv
# 115247                   N  chunk151.csv
# 230896                   N  chunk152.csv
# 151308                   N  chunk151.csv
# 701214                   N  chunk156.csv
# 389945                   N  chunk153.csv
# 753712                   N   chunk76.csv
# 326685                   N  chunk153.csv
# 147203                   N  chunk151.csv
# 657247                   N  chunk156.csv
# 605835                   N  chunk155.csv
# 443046                   N  chunk154.csv
# 333269                   N  chunk153.csv
# 641364                   N  chunk156.csv
# 412721                   N  chunk153.csv
#
# [20 rows x 32 columns]

# %%
## get basic overview of the data
## what datatypes do the different columns hold?
## how many rows and columns are there

ems_19_first_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754656 entries, 0 to 754655
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 754656 non-null  int64
#  1   INCIDENT_DATETIME               754656 non-null  object
#  2   INITIAL_CALL_TYPE               754656 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     754656 non-null  int64
#  4   FINAL_CALL_TYPE                 754656 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       754656 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       749544 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  754656 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    754656 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       748561 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         729221 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  754656 non-null  object
#  12  INCIDENT_RESPONSE_SECONDS_QY    729068 non-null  float64
#  13  INCIDENT_TRAVEL_TM_SECONDS_QY   729221 non-null  float64
#  14  FIRST_TO_HOSP_DATETIME          522462 non-null  object
#  15  FIRST_HOSP_ARRIVAL_DATETIME     518867 non-null  object
#  16  INCIDENT_CLOSE_DATETIME         754540 non-null  object
#  17  HELD_INDICATOR                  754656 non-null  object
#  18  INCIDENT_DISPOSITION_CODE       748265 non-null  float64
#  19  BOROUGH                         754656 non-null  object
#  20  INCIDENT_DISPATCH_AREA          754656 non-null  object
#  21  ZIPCODE                         745086 non-null  float64
#  22  POLICEPRECINCT                  745102 non-null  float64
#  23  CITYCOUNCILDISTRICT             745071 non-null  float64
#  24  COMMUNITYDISTRICT               745101 non-null  float64
#  25  COMMUNITYSCHOOLDISTRICT         744542 non-null  float64
#  26  CONGRESSIONALDISTRICT           745071 non-null  float64
#  27  REOPEN_INDICATOR                754656 non-null  object
#  28  SPECIAL_EVENT_INDICATOR         754656 non-null  object
#  29  STANDBY_INDICATOR               754656 non-null  object
#  30  TRANSFER_INDICATOR              754656 non-null  object
#  31  source                          754656 non-null  object
# dtypes: float64(9), int64(4), object(19)
# memory usage: 184.2+ MB

# %% [markdown]
# ### In three separate cells, ingest the 3 other related datasets into this notebook:
#
# - ```ems_2019_last_6_months.csv``` into a dataframe named ```ems_19_last_df```
# - ```ems_2020_first_6_months.csv``` into a dataframe named ```ems_20_first_df```
# - ```ems_2020_last_6_months.csv``` into a dataframe named ```ems_20_last_df```
#
# We want to combine all 4 dataframes so we can run an analysis on the combined dataframes

# %%
### For last 6 months of 2019
## call the dataframe to see what you have

ems_19_last_df = pd.read_csv("wk7-data/ems_2019_last_6_months.csv")
ems_19_last_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             191853909  2019-07-04 21:07:53              DRUG
# 1             191864927  2019-07-05 21:09:53            MVAINJ
# 2             191870823  2019-07-06 05:32:12            INJURY
# 3             191870824  2019-07-06 05:33:49               UNC
# 4             191870897  2019-07-06 06:20:26            INJURY
# ...                 ...                  ...               ...
# 781735        192702998  2019-09-27 16:20:29               EDP
# 781736        192704269  2019-09-27 21:05:14             OTHER
# 781737        193012678  2019-10-28 15:01:30            MVAINJ
# 781738        193330212  2019-11-29 01:16:42               EDP
# 781739        193634478  2019-12-29 23:59:34               EDP
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 4            DRUG
# 1                                 4          MVAINJ
# 2                                 5          INJURY
# 3                                 2             UNC
# 4                                 5          INJURY
# ...                             ...             ...
# 781735                            7          UNKNOW
# 781736                            6           OTHER
# 781737                            4          MVAINJ
# 781738                            7             EDP
# 781739                            7             EDP
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               4    07/04/2019 09:08:16 PM
# 1                               4    07/05/2019 09:10:10 PM
# 2                               5    07/06/2019 05:32:49 AM
# 3                               2    07/06/2019 05:33:57 AM
# 4                               5    07/06/2019 06:20:43 AM
# ...                           ...                       ...
# 781735                          4    09/27/2019 04:21:09 PM
# 781736                          6    09/27/2019 09:05:26 PM
# 781737                          4    10/28/2019 03:01:30 PM
# 781738                          7    11/29/2019 01:17:36 AM
# 781739                          7                       NaN
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            23
# 1                                   Y                            17
# 2                                   Y                            37
# 3                                   Y                             8
# 4                                   Y                            17
# ...                               ...                           ...
# 781735                              Y                            40
# 781736                              Y                            12
# 781737                              Y                             0
# 781738                              Y                            54
# 781739                              N                             0
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         07/04/2019 09:08:26 PM  ...            NaN                 NaN
# 1         07/05/2019 09:10:20 PM  ...            NaN                 NaN
# 2         07/06/2019 05:33:40 AM  ...           47.0                12.0
# 3         07/06/2019 05:34:25 AM  ...           32.0                 9.0
# 4         07/06/2019 06:20:53 AM  ...            NaN                 NaN
# ...                          ...  ...            ...                 ...
# 781735    09/27/2019 04:21:21 PM  ...          100.0                31.0
# 781736    09/27/2019 09:07:15 PM  ...           43.0                18.0
# 781737    10/28/2019 03:01:30 PM  ...          109.0                20.0
# 781738    11/29/2019 01:17:53 AM  ...           28.0                 9.0
# 781739                       NaN  ...           41.0                17.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                     NaN                      NaN                   NaN
# 1                     NaN                      NaN                   NaN
# 2                   212.0                     11.0                  16.0
# 3                   110.0                      5.0                  13.0
# 4                     NaN                      NaN                   NaN
# ...                   ...                      ...                   ...
# 781735              414.0                     27.0                   5.0
# 781736              209.0                      8.0                  15.0
# 781737              407.0                     25.0                   6.0
# 781738              110.0                      5.0                  13.0
# 781739              202.0                      8.0                  15.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 781735                N                       N                 N
# 781736                N                       N                 N
# 781737                N                       N                 N
# 781738                N                       N                 N
# 781739                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 0                        N  chunk157.csv
# 1                        N  chunk157.csv
# 2                        N  chunk157.csv
# 3                        N  chunk157.csv
# 4                        N  chunk157.csv
# ...                    ...           ...
# 781735                   N   chunk81.csv
# 781736                   N   chunk81.csv
# 781737                   N   chunk81.csv
# 781738                   N   chunk81.csv
# 781739                   N   chunk81.csv
#
# [781740 rows x 32 columns]

# %%
### For first 6 months of 2020
## call the dataframe to see what you have

ems_20_first_df = pd.read_csv("wk7-data/ems_2020_first_6_months.csv")
ems_20_first_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             201012966  2020-04-10 14:36:07              SICK
# 1             201013858  2020-04-10 17:37:57            SICKFC
# 2             201013897  2020-04-10 17:46:07             HYPTN
# 3             201014048  2020-04-10 18:19:32            SICKFC
# 4             201014049  2020-04-10 18:19:33            INJURY
# ...                 ...                  ...               ...
# 741802        201824116  2020-06-30 23:58:45            INJURY
# 741803        201824117  2020-06-30 23:59:00              DRUG
# 741804        201824118  2020-06-30 23:59:26            INJURY
# 741805        200293244  2020-01-29 17:15:18            UNKNOW
# 741806        200293566  2020-01-29 18:32:45              EDPC
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 6            SICK
# 1                                 6          SICKFC
# 2                                 7           HYPTN
# 3                                 6          SICKFC
# 4                                 5          INJURY
# ...                             ...             ...
# 741802                            5          INJURY
# 741803                            4            DRUG
# 741804                            5          INJURY
# 741805                            4          UNKNOW
# 741806                            7            EDPC
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               6    04/10/2020 02:36:37 PM
# 1                               6    04/10/2020 05:56:30 PM
# 2                               7    04/10/2020 05:51:43 PM
# 3                               6    04/10/2020 06:19:54 PM
# 4                               5    04/10/2020 06:25:55 PM
# ...                           ...                       ...
# 741802                          5    06/30/2020 11:58:56 PM
# 741803                          4    06/30/2020 11:59:24 PM
# 741804                          5    06/30/2020 11:59:40 PM
# 741805                          4    01/29/2020 05:47:34 PM
# 741806                          7                       NaN
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            30
# 1                                   Y                          1113
# 2                                   Y                           336
# 3                                   Y                            22
# 4                                   Y                           382
# ...                               ...                           ...
# 741802                              Y                            11
# 741803                              Y                            24
# 741804                              Y                            14
# 741805                              Y                          1936
# 741806                              N                             0
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         04/10/2020 02:37:36 PM  ...          101.0                31.0
# 1         04/10/2020 05:56:30 PM  ...           42.0                17.0
# 2         04/10/2020 05:51:47 PM  ...           62.0                43.0
# 3         04/10/2020 06:23:23 PM  ...           52.0                14.0
# 4         04/10/2020 06:26:14 PM  ...          103.0                27.0
# ...                          ...  ...            ...                 ...
# 741802    06/30/2020 11:59:18 PM  ...          106.0                28.0
# 741803    06/30/2020 11:59:40 PM  ...           61.0                47.0
# 741804    06/30/2020 11:59:57 PM  ...           30.0                 7.0
# 741805    01/29/2020 05:47:57 PM  ...           14.0                 4.0
# 741806                       NaN  ...            9.0                 2.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                   414.0                     27.0                   5.0
# 1                   203.0                     12.0                  15.0
# 2                   311.0                     20.0                  11.0
# 3                   207.0                     10.0                  13.0
# 4                   412.0                     28.0                   5.0
# ...                   ...                      ...                   ...
# 741802              410.0                     27.0                   5.0
# 741803              315.0                     21.0                  11.0
# 741804              109.0                      6.0                  13.0
# 741805              105.0                      2.0                  12.0
# 741806              102.0                      2.0                  12.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 741802                N                       N                 N
# 741803                N                       N                 N
# 741804                N                       N                 N
# 741805                N                       N                 N
# 741806                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 0                        N  chunk148.csv
# 1                        N  chunk148.csv
# 2                        N  chunk148.csv
# 3                        N  chunk148.csv
# 4                        N  chunk148.csv
# ...                    ...           ...
# 741802                   N  chunk172.csv
# 741803                   N  chunk172.csv
# 741804                   N  chunk172.csv
# 741805                   N   chunk81.csv
# 741806                   N   chunk81.csv
#
# [741807 rows x 32 columns]

# %%
### For last 6 months of 2020
## call the dataframe to see what you have

ems_20_last_df = pd.read_csv("wk7-data/ems_2020_last_6_months.csv")
ems_20_last_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             201853344  2020-07-03 19:51:35            MVAINJ
# 1             201861781  2020-07-04 13:38:45            INJURY
# 2             201862931  2020-07-04 19:06:08            INJURY
# 3             201870048  2020-07-05 00:09:31              SICK
# 4             201870159  2020-07-05 00:31:24              EDPC
# ...                 ...                  ...               ...
# 670750        203664156  2020-12-31 23:58:15            DIFFBR
# 670751        203664157  2020-12-31 23:58:27            INJURY
# 670752        203664158  2020-12-31 23:58:38            CARDBR
# 670753        203664159  2020-12-31 23:58:46            MVAINJ
# 670754        203664161  2020-12-31 23:59:13            CARDBR
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 4          MVAINJ
# 1                                 5          INJURY
# 2                                 5          INJURY
# 3                                 6            SICK
# 4                                 7            SICK
# ...                             ...             ...
# 670750                            2          DIFFBR
# 670751                            5          INJURY
# 670752                            2          CARDBR
# 670753                            4          MVAINJ
# 670754                            2          CARDBR
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               4    07/03/2020 07:52:54 PM
# 1                               5    07/04/2020 01:38:55 PM
# 2                               5    07/04/2020 07:06:34 PM
# 3                               6                       NaN
# 4                               6                       NaN
# ...                           ...                       ...
# 670750                          2    12/31/2020 11:58:26 PM
# 670751                          5    12/31/2020 11:59:57 PM
# 670752                          2    12/31/2020 11:59:32 PM
# 670753                          4    12/31/2020 11:59:37 PM
# 670754                          2    01/01/2021 12:00:22 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            79
# 1                                   Y                            10
# 2                                   Y                            26
# 3                                   N                             0
# 4                                   N                             0
# ...                               ...                           ...
# 670750                              Y                            11
# 670751                              Y                            90
# 670752                              Y                            54
# 670753                              Y                            51
# 670754                              Y                            69
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         07/03/2020 07:53:13 PM  ...            NaN                 NaN
# 1         07/04/2020 01:39:01 PM  ...           20.0                 3.0
# 2         07/04/2020 07:06:53 PM  ...           60.0                47.0
# 3                            NaN  ...           46.0                14.0
# 4                            NaN  ...           43.0                17.0
# ...                          ...  ...            ...                 ...
# 670750    12/31/2020 11:59:10 PM  ...           79.0                36.0
# 670751    01/01/2021 12:01:00 AM  ...           41.0                17.0
# 670752    12/31/2020 11:59:40 PM  ...           30.0                 7.0
# 670753    01/01/2021 12:01:00 AM  ...           48.0                17.0
# 670754    01/01/2021 12:01:10 AM  ...           77.0                36.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                     NaN                      NaN                   NaN
# 1                   107.0                      3.0                  10.0
# 2                   313.0                     21.0                   8.0
# 3                   205.0                     10.0                  15.0
# 4                   209.0                     12.0                  15.0
# ...                   ...                      ...                   ...
# 670750              303.0                     14.0                   7.0
# 670751              202.0                      8.0                  15.0
# 670752              109.0                      6.0                  13.0
# 670753              206.0                     12.0                  15.0
# 670754              308.0                     16.0                   9.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 670750                N                       N                 N
# 670751                N                       N                 N
# 670752                N                       N                 N
# 670753                N                       N                 N
# 670754                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 0                        N  chunk172.csv
# 1                        N  chunk172.csv
# 2                        N  chunk172.csv
# 3                        N  chunk172.csv
# 4                        N  chunk172.csv
# ...                    ...           ...
# 670750                   N  chunk214.csv
# 670751                   N  chunk214.csv
# 670752                   N  chunk214.csv
# 670753                   N  chunk214.csv
# 670754                   N  chunk214.csv
#
# [670755 rows x 32 columns]

# %% [markdown]
# ### Check if all the column headers are identical (down to the same order)
# We need to confirm they are the same before we combine them

# %%
## headers for first 6 months of 2019

headers_19_f = list(ems_19_first_df.columns)
headers_19_f
# Out:
# ['CAD_INCIDENT_ID',
#  'INCIDENT_DATETIME',
#  'INITIAL_CALL_TYPE',
#  'INITIAL_SEVERITY_LEVEL_CODE',
#  'FINAL_CALL_TYPE',
#  'FINAL_SEVERITY_LEVEL_CODE',
#  'FIRST_ASSIGNMENT_DATETIME',
#  'VALID_DISPATCH_RSPNS_TIME_INDC',
#  'DISPATCH_RESPONSE_SECONDS_QY',
#  'FIRST_ACTIVATION_DATETIME',
#  'FIRST_ON_SCENE_DATETIME',
#  'VALID_INCIDENT_RSPNS_TIME_INDC',
#  'INCIDENT_RESPONSE_SECONDS_QY',
#  'INCIDENT_TRAVEL_TM_SECONDS_QY',
#  'FIRST_TO_HOSP_DATETIME',
#  'FIRST_HOSP_ARRIVAL_DATETIME',
#  'INCIDENT_CLOSE_DATETIME',
#  'HELD_INDICATOR',
#  'INCIDENT_DISPOSITION_CODE',
#  'BOROUGH',
#  'INCIDENT_DISPATCH_AREA',
#  'ZIPCODE',
#  'POLICEPRECINCT',
#  'CITYCOUNCILDISTRICT',
#  'COMMUNITYDISTRICT',
#  'COMMUNITYSCHOOLDISTRICT',
#  'CONGRESSIONALDISTRICT',
#  'REOPEN_INDICATOR',
#  'SPECIAL_EVENT_INDICATOR',
#  'STANDBY_INDICATOR',
#  'TRANSFER_INDICATOR',
#  'source']

# %%
## headers for first 6 months of 2020

headers_20_f = list(ems_20_first_df.columns)
headers_20_f
# Out:
# ['CAD_INCIDENT_ID',
#  'INCIDENT_DATETIME',
#  'INITIAL_CALL_TYPE',
#  'INITIAL_SEVERITY_LEVEL_CODE',
#  'FINAL_CALL_TYPE',
#  'FINAL_SEVERITY_LEVEL_CODE',
#  'FIRST_ASSIGNMENT_DATETIME',
#  'VALID_DISPATCH_RSPNS_TIME_INDC',
#  'DISPATCH_RESPONSE_SECONDS_QY',
#  'FIRST_ACTIVATION_DATETIME',
#  'FIRST_ON_SCENE_DATETIME',
#  'VALID_INCIDENT_RSPNS_TIME_INDC',
#  'INCIDENT_RESPONSE_SECONDS_QY',
#  'INCIDENT_TRAVEL_TM_SECONDS_QY',
#  'FIRST_TO_HOSP_DATETIME',
#  'FIRST_HOSP_ARRIVAL_DATETIME',
#  'INCIDENT_CLOSE_DATETIME',
#  'HELD_INDICATOR',
#  'INCIDENT_DISPOSITION_CODE',
#  'BOROUGH',
#  'INCIDENT_DISPATCH_AREA',
#  'ZIPCODE',
#  'POLICEPRECINCT',
#  'CITYCOUNCILDISTRICT',
#  'COMMUNITYDISTRICT',
#  'COMMUNITYSCHOOLDISTRICT',
#  'CONGRESSIONALDISTRICT',
#  'REOPEN_INDICATOR',
#  'SPECIAL_EVENT_INDICATOR',
#  'STANDBY_INDICATOR',
#  'TRANSFER_INDICATOR',
#  'source']

# %%
## check if they are the same

headers_19_f == headers_20_f
# Out:
# True

# %%
## creater headers list for last 6 months of 2019 and 2020

headers_20_last = list(ems_20_last_df.columns)
headers_19_last = list(ems_19_last_df.columns)

# %%
## check if one of the first is equal to one of the last

headers_19_f == headers_20_last
# Out:
# True

# %%
## now confirm that the two lasts are the same
headers_20_last == headers_19_last
# Out:
# True

# %% [markdown]
# ## Combine the 4 dataframes

# %%
## create a list to combine all 
combine_these_dfs = [ems_19_first_df, ems_19_last_df, ems_20_first_df, ems_20_last_df]

# %%
## combine the dfs

ems_2_yrs= pd.concat(combine_these_dfs)

# %% [markdown]
# #### Confirm that their row totals add up to the correct number

# %%
## how many rows does the combined df have

ems_2_yrs.shape
# Out:
# (2948958, 32)

# %%
## get total rows when you add up all the individual dataframes
ems_2_yrs.shape[0] == ems_19_first_df.shape[0] + ems_19_last_df.shape[0] + ems_20_first_df.shape[0] + ems_20_last_df.shape[0]
# Out:
# True

# %% [markdown]
# ## Ingest Massive Dataset
#
# Step 1. Open this dataset in Excel first. What happened?
#
# Step 2. Open this data set in Pandas.

# %%
## import global_temps.csv into a df called temps_df

temps_df = pd.read_csv("wk7-data/global_temps.csv")
temps_df.head()
# Out:
#    Region  Country     City  Month  Day  Year  AvgTemperature
# 0  Africa  Algeria  Algiers      1    1  1995            64.2
# 1  Africa  Algeria  Algiers      1    2  1995            49.4
# 2  Africa  Algeria  Algiers      1    3  1995            48.8
# 3  Africa  Algeria  Algiers      1    4  1995            46.4
# 4  Africa  Algeria  Algiers      1    5  1995            47.9

# %%
temps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906327 entries, 0 to 2906326
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Region          object
#  1   Country         object
#  2   City            object
#  3   Month           int64
#  4   Day             int64
#  5   Year            int64
#  6   AvgTemperature  float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 155.2+ MB

# %%
temps_df.sample(20)
# Out:
#                                     Region        Country            City  \
# 1715247                      North America             US    Jacksonville
# 1567084                      North America             US          Fresno
# 425371                                Asia       Mongolia      Ulan-bator
# 1425690  South/Central America & Carribean       Suriname      Paramaribo
# 266969                                Asia          China         Chengdu
# 1572976                      North America             US     Los Angeles
# 1632150                      North America             US  Grand Junction
# 1157677                      North America         Canada          Ottawa
# 290187                                Asia          China        Shanghai
# 1375633  South/Central America & Carribean         Guyana      Georgetown
# 87245                               Africa  Guinea-Bissau          Bissau
# 2274763                      North America             US          Albany
# 2851895                      North America             US          Elkins
# 2547045                      North America             US    Wilkes Barre
# 185729                              Africa        Senegal           Dakar
# 2179198                      North America             US     Great Falls
# 2277981                      North America             US          Albany
# 2027088                      North America             US        Portland
# 862517                              Europe       Portugal          Lisbon
# 1042973                        Middle East        Lebanon          Beirut
#
#          Month  Day  Year  AvgTemperature
# 1715247      9   16  2005            80.0
# 1567084      1   17  2012            39.1
# 425371       6   18  2002           -99.0
# 1425690     11    4  2001            82.9
# 266969       2   14  1997           -99.0
# 1572976     10   23  2002            61.1
# 1632150      8   15  2012            75.1
# 1157677      9    9  1995            54.1
# 290187      12   14  2009            48.7
# 1375633     12   18  2000            82.4
# 87245        1   13  1995           -99.0
# 2274763      9   27  1999            59.4
# 2851895     10    2  2016            59.6
# 2547045      3   17  2019            33.3
# 185729       4   30  2004            69.3
# 2179198      2   13  2017            40.4
# 2277981      7   19  2008            77.1
# 2027088      7   11  2006            68.3
# 862517       8   25  2002            70.0
# 1042973      2   23  2009            54.1

# %% [markdown]
# ## How many rows of data does this dataset have?

# %%
## 2_906_327

# %% [markdown]
# ## Targeting an Excel sheet
#
# We need the Customs and Border Protection data in this ```multi-data.xlsx``` workbook.
#
# Note that this is an excerpt of the actual CBP data.

# %%
## import data here
cbp_df = pd.read_excel("wk7-data/multi-data.xlsx", sheet_name = "CBP", skiprows= 6)

# %%
## call the top 15 rows

cbp_df.head(5)
# Out:
#               date_in            date_out  hours_in_custody    age_group  \
# 0 2017-01-20 00:10:00 2017-01-20 10:08:00          9.950000    6-8 years
# 1 2017-01-20 00:15:00 2017-01-24 17:30:00        113.233333    3-5 years
# 2 2017-01-20 00:22:00 2017-01-24 17:47:00        113.416667    3-5 years
# 3 2017-01-20 00:30:00 2017-01-21 06:35:00         30.083333  12-14 years
# 4 2017-01-20 00:30:00 2017-01-21 13:03:00         36.533333    3-5 years
#
#    gender  citizenship border      sector  field_office
# 0  Female  EL SALVADOR    SBO  (b)(7)(E )           NaN
# 1  Female    GUATEMALA    SBO  (b)(7)(E )           NaN
# 2  Female       BRAZIL    SBO  (b)(7)(E )           NaN
# 3    Male  EL SALVADOR    SBO  (b)(7)(E )           NaN
# 4    Male     HONDURAS    SBO  (b)(7)(E )           NaN
