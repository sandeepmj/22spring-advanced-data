# %% [markdown]
# # Solution
#
# A video that takes you through the GitHub process required for this homework can be found in our <a href="https://www.dropbox.com/sh/fm0k4i98ra9em9d/AAB39jgN_HKnfuEfAdcdM7X0a?dl=0">course Dropbox folder</a>.

# %% [markdown]
# # GitHub
#
# In this homework, you are asked to create a repository and then to push various commits to the code.
#
# You must use  ```command line``` to navigatate through your directories except where noted to use Jupyter.
#
# The focus is on the GitHub process and less about the Python code.

# %% [markdown]
# ### Step 1. Create a repo
#
# Create a repo called ```homework-demo```.

# %% [markdown]
# ### Step 2. Clone a repo
#
# Clone the ```homework-demo``` to your computer.
#
# Try to stay organized and consider where you want to place your cloned repo.

# %% [markdown]
# ### Step. 3 Create a Jupyter Notebook file
#
# Remember to use Jupyter to navigate (see image below) into your cloned directory before you create an ```.ipynb``` file.
#
# ![Screen%20Shot%202022-03-08%20at%204.04.23%20PM.png](attachment:Screen%20Shot%202022-03-08%20at%204.04.23%20PM.png)

# %% [markdown]
# ### Step 4. Transfer questions
#
# Copy and paste each question into a new coding cell in your newly created notebook.
#
# **Don't write the code to answer the questions yet**

# %%
## Question 1
## write a conditional expression that compares x and y and 
## prints "x is larger than y" if x is larger than y or
## prints "x is smaller than y" if x is smaller than y

x = 10
y = 15

if x > y:
    print("x is larger than y")
elif x < y:
    print("x is smaller than y")
else:
    print("x and y are equal")
# Out:
# x is smaller than y

# %%
## Question 2
## write a for loop that prints the values in this list but increases each number by 5
numbers = [1, 6, 11, 16, 21]

for number in numbers:
    print(number + 5)
# Out:
# 6
# 11
# 16
# 21
# 26

# %%
## Question 3
## add these two numbers together and round to 2 decimal places
number_1 = 42.569783
number_2 = 101.668342
total = round(number_1 + number_2, 2)
total
# Out:
# 144.24

# %% [markdown]
# ### Step 5. Git commands
#
# 1. After copying all questions into your own notebook, save this to your GitHub repo and use the commit description of ```initial commit```.
#
# 2. Now, after you answer each question, commit it with the following messages respectively:
# - ```question 1 done```
# - ```question 2 done```
# - ```question 3 done```
#
# When you're completely done your repo should show a commit message for each version in the history section:
#
# ```question 3 done```
#
# ```question 2 done```
#
# ```question 1 done```
#
# ```initial commit```
