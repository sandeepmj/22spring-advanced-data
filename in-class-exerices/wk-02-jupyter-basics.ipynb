# %% [markdown]
# # code v. markup

# %% [markdown]
# Code cells allow you to run code while markup cells let you write headings, notes, lists, etc.

# %% [markdown]
# #### do historical "hello world"

# %%
print("hello world")

# %%
## what version of Python to I have?
# !python --version

# %%
## simple calculation 1
2 + 2

# %%
## simple calculation 2

25 / 5

# %%
## simple calculation 3

10 % 2

# %%
## simple calculation 4

25 % 2

# %%
25 % 3

# %%
25 % 7

# %% [markdown]
# # Markup

# %% [markdown]
# # This is how big the text is 1

# %% [markdown]
# ## This is how big the text is 2

# %% [markdown]
# ### This is how big the text is 3

# %% [markdown]
# # List of items
#
# Here is a list of items I need to complete:
# - Walk the dog
# - Water the plants
# - Make the bed

# %% [markdown]
# #### Linking to data or anything else
# I got this data from the <a href="https://www.census.gov/manufacturing/m3/index.html">U.S. Census site</a>

# %% [markdown]
# ## Insert image
# ![Screen%20Shot%202022-02-03%20at%201.56.50%20PM.png](attachment:Screen%20Shot%202022-02-03%20at%201.56.50%20PM.png)

# %%
print("Hello")
print("My name is Sandeep")
print("I'm teaching students to use Python and Pandas for data analysis this semester")

# %%
print("Bye")

# %% [markdown]
#  ## add line numbers to the code above

# %% [markdown]
# ## add cell above

# %% [markdown]
# ## add cell below

# %% [markdown]
# ## clear all the cell results

# %%
## Write some code here and then clear the result

2 + 5

# %% [markdown]
# ## save the notebook checkpoint

# %%
(50000 / 41) * 210

# %%
((20-10) / 10) * 100

# %% [markdown]
# ## Revert to previous notebook checkpoint
#
# - notice how the last two cells disappeared.
# - this is NOT the ideal way to do version control. We will start working on that in a few weeks using GitHub.
